# %%
import requests
from bs4 import BeautifulSoup

url = "https://basketball.realgm.com/nba/draft/future_drafts/team"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

tables = soup.find_all("table", class_="basketball sortable")  # each team's table

for table in tables:
    team_name = table.find_previous("h2").text.strip()
    for row in table.select("tr")[1:]:
        cols = [td.text.strip() for td in row.find_all("td")]
        print(team_name, cols)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <!-- START email detection script -->
# <script>
#
#        !function(){"use strict";var e=window.location.search.substring(1).split("&");const t=e=>e.replace(/\s/g,""),o=e=>new Promise((t=>{if(!("msCrypto"in window)&&"https:"===location.protocol&&"crypto"in window&&"TextEncoder"in window){const o=(new TextEncoder).encode(e);crypto.subtle.digest("SHA-256",o).then((e=>{const o=Array.from(new Uint8Array(e)).map((e=>("00"+e.toString(16)).slice(-2))).join("");t(o)}))}else t("")}));for(var n=0;n<e.length;n++){var r="adt_ei",i=decodeURIComponent(e[n]);if(0===i.indexOf(r)){var a=i.split(r+"=")[1];if((e=>{const t=e.match(/((?=([a-zA-Z0-9._!#$%+^&*()[\]<>-]+))\2@[a-zA-Z0-9._-]+\.[a-zA-Z0-9._-]+)/gi);return t?t[0]:""})(t(a.toLowerCase()))){o(a).then((t=>{t.length&&(localStorage.setItem(r,t),localStorage.setItem("adt_emsrc","url"),e.splice(n,1),history.replaceState(null,"","?"+e.join("&")))}));break}}}}();
#
#        </script>
# <!-- END email detection script -->
# <!-- AdThrive Head Tag Manual -->
# <script data-cfasync="false" data-no-optimize="1">
#    (function(w, d) {
#       w.adthrive = w.adthrive || {};
#       w.adthrive.cmd = w.
#       adthrive.cmd || [];
#       w.adthrive.plugin = 'adthrive-ads-manual';
#       w.adthrive.host = 'ads.adthrive.com';var s = d.createElement('script');
#       s.async = true;
#       s.referrerpolicy='no-referrer-when-downgrade';
#       s.src = 'https://' + w.adthrive.host + '/sites/6644e66132a7901cb0ab5997/ads.min.js?referrer=' + w.encodeURIComponent(w.location.href) + '&cb=' + (Math.floor(Math.random() * 100) + 1);
#       var n = d.getElementsByTagName('script')[0];
#       n.parentNode.insertBefore(s, n);
#    })(window, document);
#    </script>
# <!-- End of AdThrive Head Tag -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TNR4DGVD');</script>
# <!-- End Google Tag Manager -->
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <title>NBA Future Drafts By Team - RealGM</title>
# <script type="application/ld+json">
# {
#   "@context": "https://schema.org",
#   "@type": "WebSite",
#   "name": "RealGM",
#   "url": "https://basketball.realgm.com/"
# }
# </script>
# <link href="https://basketball.realgm.com/nba/draft/future_drafts/team" rel="canonical"/>
# <meta content="https://www.facebook.com/RealGM" property="article:publisher"/>
# <meta content="305642309526726" property="fb:app_id"/>
# <meta content="NBA Future Drafts By Team, RealGM" name="keywords"/>
# <meta content="NBA Future Drafts By Team - RealGM" name="description"/>
# <meta content="nba_draft_future_summary_by_team" property="rgm:pageid"/>
# <meta content="2025-07-26 22:29:22" property="rgm:datetime"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=5" name="viewport"/>
# <link href="/css/normalize.min.css" rel="stylesheet"/>
# <link href="/css/main.v19.css" rel="stylesheet"/>
# <script src="/js/vendor/modernizr-2.6.2-respond-1.1.0.min.js"></script>
# <script src="/js/vendor/jquery-1.11.0.min.js"></script>
# <link href="/css/bootstrap-table.min.css" rel="stylesheet"/>
# <script src="/js/bootstrap-table.min.js"></script>
# <link href="/js/extensions/sticky-header/bootstrap-table-sticky-header.css" rel="stylesheet"/>
# <script src="/js/extensions/sticky-header/bootstrap-table-sticky-header.js"></script>
# <script>
# window.grunticon=function(e){if(e&&3===e.length){var t=window,n=!(!t.document.createElementNS||!t.document.createElementNS("https://www.w3.org/2000/svg","svg").createSVGRect||!document.implementation.hasFeature("https://www.w3.org/TR/SVG11/feature#Image","1.1")||window.opera&&-1===navigator.userAgent.indexOf("Chrome")),o=function(o){var r=t.document.createElement("link"),a=t.document.getElementsByTagName("script")[0];r.rel="stylesheet",r.href=e[o&&n?0:o?1:2],a.parentNode.insertBefore(r,a)},r=new t.Image;r.onerror=function(){o(!1)},r.onload=function(){o(1===r.width&&1===r.height)},r.src="..."}};
# grunticon(["/css/icons.data.svg.css", "/css/icons.data.png.css", "/css/icons.fallback.css"]);
# </script>
# <noscript><link href="/css/icons.fallback.css" rel="stylesheet"/></noscript>
# <link href="/css/ui/jquery-ui.min.css" rel="stylesheet"/>
# <script src="/js/vendor/jquery-ui.min.js"></script>
# <!-- SendToNews -->
# <script>
#    window.addEventListener('message',function(event) {
#       if(event.data.type !== 's2nEvent' || event.data.s2nEvent !== 'readyToPlay') {
#          return;
#       }
#       ga('send', {
#          hitType: 'event',
#          eventCategory: 'SendtoNews Player',
#          eventAction: 'readyToPlay',
#          eventLabel: event.data.playerKey,
#          nonInteraction: true
#       });
#    });
# </script>
# <link as="image" href="/images/icons/basketball-color.png" rel="preload">
# <link as="image" href="/images/icons/baseball-color.png" rel="preload">
# <link as="image" href="/images/icons/football-color-2.png" rel="preload">
# <link as="image" href="/images/icons/hockey-color.png" rel="preload">
# <link as="image" href="/images/icons/soccer-color-2.png" rel="preload">
# <link as="image" href="/images/icons/forums-color.png" rel="preload">
# <link as="image" href="/images/icons/tickets-color.png" rel="preload"/>
# </link></link></link></link></link></link></head>
# <body class="raptive page_nba_draft_future_summary_by_team dev3">
# <div id="site-takeover">
# <div id="header_wrap">
# <header class="wrapper clearfix">
# <div class="container">
# <div class="tabs-container clearfix">
# <div class="logo-container clearfix">
# <a href="/"><img alt="RealGM" class="logo" src="/images/icons/realgm-black-80-alt.png"/></a>
# </div>
# <div class="secondary-ad-container"></div>
# <div class="topmenu" id="sports-menu">
# <div id="sports-menu-container">
# <ul>
# <li class="top-icon navitem nbalink selected"><a href="https://basketball.realgm.com/" title="Basketball"><span></span><nav>NBA</nav></a></li>
# <li class="top-icon navitem nfllink"><a href="https://football.realgm.com/" title="Football"><span></span><nav>NFL</nav></a></li>
# <li class="top-icon navitem mlblink"><a href="https://baseball.realgm.com/" title="Baseball"><span></span><nav>MLB</nav></a></li>
# <li class="top-icon navitem soccerlink"><a href="https://soccer.realgm.com/" title="Soccer"><span></span><nav>Soccer</nav></a></li>
# <li class="top-icon navitem nhllink"><a href="https://hockey.realgm.com/" title="Hockey"><span></span><nav>NHL</nav></a></li>
# <li class="top-icon navitem forumlink"><a href="https://forums.realgm.com/boards/index.php" title="Forums"><span></span><nav>Forums</nav></a></li>
# <li class="top-icon navitem tixlink"><a href="https://www.vividseats.com/?wsUser=958" target="_blank" title="Tickets"><span></span><nav>Tickets</nav></a></li>
# <li class="top-icon navitem searchlink"><a href="#" onclick="showSearchbar()" title="Search"><span></span><nav>Search</nav></a></li>
# </ul>
# </div>
# </div>
# <div class="searchbar">
# <form action="/search" autocomplete="off" class="searchbox" id="playersearch" method="get">
# <input class="searchbox-text" id="searchfield" name="q" onkeyup="searchButtonUp();" placeholder="Search..." required="required" type="text"/><input class="searchbox-submit" type="submit" value="Go"/>
# </form>
# </div>
# </div>
# </div>
# </header>
# <div class="top-nav-container">
# <div class="wrapper clearfix">
# <nav class="container" id="top-level-nav" role="navigation">
# <ul class="primary-nav">
# <li class="has-subnav" style="border-right: 1px solid #BCBCBC;">
# <a href="/leagues" id="change-sports-menu">Leagues<span class="primary-nav-ddl-icon">▾</span></a>
# <div class="primary-nav-ddl">
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/leagues">Leagues</a></p><ul>
# <li style="float: left; margin-right: 1em;"><a href="/nba">NBA</a></li><li style="float: left; margin-right: 1em;"><a href="/gleague">G League</a></li><li style="float: left; margin-right: 1em;"><a href="/ncaa">NCAA</a></li><li style="float: left; margin-right: 1em;"><a href="/international">International</a></li><li style="float: left; margin-right: 1em;"><a href="/national">National</a></li><li style="float: left; margin-right: 1em;"><a href="/highschool">High School</a></li><li style="float: left; margin-right: 1em;"><a href="/wnba">WNBA</a></li></ul>
# </div>
# <div style="clear: both;"></div>
# </li><li><a href="/nba"><span>NBA</span></a></li><li class="has-subnav">
# <a href="https://forums.realgm.com/boards/viewforum.php?f=243">Forums<span class="primary-nav-ddl-icon">▾</span></a>
# <div class="primary-nav-ddl">
# <div style="float: left;">
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="https://forums.realgm.com/boards/viewforum.php?f=243">Basketball Forums</a></p><ul class="primary-nav-col" style="width: 14em;">
# <li><a href="https://forums.realgm.com/boards/viewforum.php?f=6">The General Board</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=64">Player Comparisons</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=2">Trades &amp; Transactions</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=39">Fantasy Basketball</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=3">NBA Draft</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=472">WNBA</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=42">Off-Topic Board</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=40">Feedback</a></li></ul>
# </div>
# <div style="float: left; border-left: 1px solid white; padding-left: 1em;">
# <div style="float: left; width: 14em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Atlantic Division</p>
# <ul class="primary-nav-col">
# <li><a href="https://forums.realgm.com/boards/viewforum.php?f=8"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/2-bos-celtics.png" style="height: 25px;"/> Boston Celtics</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=23"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/38-brooklyn-nets.png" style="height: 25px;"/> Brooklyn Nets</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=24"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/20-ny-knicks.png" style="height: 25px;"/> New York Knicks</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=26"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/22-phi-sixers.png" style="height: 25px;"/> Philadelphia Sixers</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=32"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/28-toronto-raptors.png" style="height: 25px;"/> Toronto Raptors</a></li></ul>
# </div>
# <div style="float: left; width: 14em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Central Division</p>
# <ul class="primary-nav-col">
# <li><a href="https://forums.realgm.com/boards/viewforum.php?f=10"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/4-chi-bulls.png" style="height: 25px;"/> Chicago Bulls</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=11"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/5-cle-cavs.png" style="height: 25px;"/> Cleveland Cavaliers</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=14"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/8-det-pistons.png" style="height: 25px;"/> Detroit Pistons</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=17"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/11-indiana-pacers.png" style="height: 25px;"/> Indiana Pacers</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=21"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/16-milwaukee-bucks.png" style="height: 25px;"/> Milwaukee Bucks</a></li></ul>
# </div>
# <div style="float: left; width: 14em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Southeast Division</p>
# <ul class="primary-nav-col">
# <li><a href="https://forums.realgm.com/boards/viewforum.php?f=7"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/1-atl-hawks.png" style="height: 25px;"/> Atlanta Hawks</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=53"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/3-cha-hornets.png" style="height: 25px;"/> Charlotte Hornets</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=20"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/15-miami-heat.png" style="height: 25px;"/> Miami Heat</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=25"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/21-orlando-magic.png" style="height: 25px;"/> Orlando Magic</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=35"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/30-was-wizards.png" style="height: 25px;"/> Washington Wizards</a></li></ul>
# </div>
# <div style="float: left; width: 15em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Northwest Division</p>
# <ul class="primary-nav-col">
# <li><a href="https://forums.realgm.com/boards/viewforum.php?f=13"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/7-den-nuggets.png" style="height: 25px;"/> Denver Nuggets</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=22"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/17-min-wolves.png" style="height: 25px;"/> Minnesota Timberwolves</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=334"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/33-okc-thunder.png" style="height: 25px;"/> Oklahoma City Thunder</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=28"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/24-por-blazers.png" style="height: 25px;"/> Portland Trail Blazers</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=33"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/29-utah-jazz.png" style="height: 25px;"/> Utah Jazz</a></li></ul>
# </div>
# <div style="float: left; width: 14em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Pacific Division</p>
# <ul class="primary-nav-col">
# <li><a href="https://forums.realgm.com/boards/viewforum.php?f=15"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/9-golden-state.png" style="height: 25px;"/> Golden State Warriors</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=18"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/12-la-clippers.png" style="height: 25px;"/> Los Angeles Clippers</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=19"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/13-la-lakers.png" style="height: 25px;"/> Los Angeles Lakers</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=27"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/23-phx-suns.png" style="height: 25px;"/> Phoenix Suns</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=29"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/25-sac-kings.png" style="height: 25px;"/> Sacramento Kings</a></li></ul>
# </div>
# <div style="float: left; width: 14em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Southwest Division</p>
# <ul class="primary-nav-col">
# <li><a href="https://forums.realgm.com/boards/viewforum.php?f=12"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/6-dallas-mavs.png" style="height: 25px;"/> Dallas Mavericks</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=16"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/10-houston-rockets.png" style="height: 25px;"/> Houston Rockets</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=34"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/14-memphis-grizzli.png" style="height: 25px;"/> Memphis Grizzlies</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=9"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/19-new-orleans-pel.png" style="height: 25px;"/> New Orleans Pelicans</a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=30"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/26-san-antonio-spu.png" style="height: 25px;"/> San Antonio Spurs</a></li></ul>
# </div>
# </div>
# <div style="clear: both;"></div>
# </div>
# </li><li>
# <a href="/nba/news">News<span class="primary-nav-ddl-icon">▾</span></a>
# <div class="primary-nav-ddl">
# <div class="portal" style="float: left; padding-right: 1%; width: 49%;">
# <div>
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/news">Wiretap</a></p>
# <ul style="padding-left: 0.5em"><li>
# • <a href="/wiretap/281510/Lakers-Believed-To-Prefer-To-Let-LeBron-James-Leave-After-2025-26-Season" style="padding-left: 0; display: inline-block;">Lakers Believed To Prefer To Let LeBron James Leave After 2025-26 Season</a>
# </li>
# <li>
# • <a href="/wiretap/281512/Gabe-Madsen-Heat-Agree-To-Exhibit-10-Deal" style="padding-left: 0; display: inline-block;">Gabe Madsen, Heat Agree To Exhibit 10 Deal</a>
# </li>
# <li>
# • <a href="/wiretap/281511/TyTy-Washington-Jr-Clippers-Agree-To-One-Year-Deal" style="padding-left: 0; display: inline-block;">TyTy Washington Jr., Clippers Agree To One-Year Deal</a>
# </li>
# <li>
# • <a href="/wiretap/281516/Jordan-Miller-Clippers-Agree-To-Two-Year-Deal" style="padding-left: 0; display: inline-block;">Jordan Miller, Clippers Agree To Two-Year Deal</a>
# </li>
# <li>
# • <a href="/wiretap/281518/Isaiah-Crawford-Rockets-Agree-To-Two-Way-Deal" style="padding-left: 0; display: inline-block;">Isaiah Crawford, Rockets Agree To Two-Way Deal</a>
# </li>
# </ul>
# <div style="clear: both;"></div>
# </div>
# </div>
# <div class="portal" style="float: left; border-left: 1px solid white; padding-left: 1%; width: 48%;">
# <div>
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/news/analysis">Analysis</a></p><ul style="padding-left: 0.5em"><li>
# • <a href="/analysis/281493/The-Summer-That-The-Guards-Ran-Home" style="padding-left: 0; display: inline-block;">The Summer That The Guards Ran Home</a>
# <span class="author-details" style="color: #AAA;">
# by <a href="/news/analysis/author/226/John-Wilmes" style="text-decoration: none;">John Wilmes</a></span>
# </li>
# <li>
# • <a href="/analysis/281427/The-Humbling-Of-Basketballs-King" style="padding-left: 0; display: inline-block;">The Humbling Of Basketball's King</a>
# <span class="author-details" style="color: #AAA;">
# by <a href="/news/analysis/author/226/John-Wilmes" style="text-decoration: none;">John Wilmes</a></span>
# </li>
# <li>
# • <a href="/analysis/281356/Jonas-Valanciunas-Will-Stay-In-America-For-Now" style="padding-left: 0; display: inline-block;">Jonas Valanciunas Will Stay In America, For Now</a>
# <span class="author-details" style="color: #AAA;">
# by <a href="/news/analysis/author/226/John-Wilmes" style="text-decoration: none;">John Wilmes</a></span>
# </li>
# <li>
# • <a href="/analysis/281280/2026-NBA-Draft-Top-10-Prospects-To-Watch" style="padding-left: 0; display: inline-block;">2026 NBA Draft: Top 10 Prospects To Watch</a>
# <span class="author-details" style="color: #AAA;">
# by <a href="/news/analysis/author/258/Zachary-Cohen" style="text-decoration: none;">Zachary Cohen</a></span>
# </li>
# <li>
# • <a href="/analysis/281237/The-NBA-Is-Realigning-Again" style="padding-left: 0; display: inline-block;">The NBA Is Realigning (Again)</a>
# <span class="author-details" style="color: #AAA;">
# by <a href="/news/analysis/author/226/John-Wilmes" style="text-decoration: none;">John Wilmes</a></span>
# </li>
# </ul>
# <div style="clear: both;"></div>
# </div>
# </div>
# <div style="clear: both;"></div>
# </div>
# </li><li class="has-subnav">
# <a href="/nba/teams">Teams<span class="primary-nav-ddl-icon">▾</span></a>
# <div class="primary-nav-ddl">
# <div style="float: left; width: 16em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Atlantic Division</p>
# <ul class="primary-nav-col">
# <li><a href="/nba/teams/Boston-Celtics/2/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/2-bos-celtics.png" style="height: 25px;"/> Boston Celtics</a></li><li><a href="/nba/teams/Brooklyn-Nets/38/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/38-brooklyn-nets.png" style="height: 25px;"/> Brooklyn Nets</a></li><li><a href="/nba/teams/New-York-Knicks/20/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/20-ny-knicks.png" style="height: 25px;"/> New York Knicks</a></li><li><a href="/nba/teams/Philadelphia-Sixers/22/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/22-phi-sixers.png" style="height: 25px;"/> Philadelphia Sixers</a></li><li><a href="/nba/teams/Toronto-Raptors/28/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/28-toronto-raptors.png" style="height: 25px;"/> Toronto Raptors</a></li></ul>
# </div>
# <div style="float: left; width: 16em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Central Division</p>
# <ul class="primary-nav-col">
# <li><a href="/nba/teams/Chicago-Bulls/4/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/4-chi-bulls.png" style="height: 25px;"/> Chicago Bulls</a></li><li><a href="/nba/teams/Cleveland-Cavaliers/5/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/5-cle-cavs.png" style="height: 25px;"/> Cleveland Cavaliers</a></li><li><a href="/nba/teams/Detroit-Pistons/8/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/8-det-pistons.png" style="height: 25px;"/> Detroit Pistons</a></li><li><a href="/nba/teams/Indiana-Pacers/11/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/11-indiana-pacers.png" style="height: 25px;"/> Indiana Pacers</a></li><li><a href="/nba/teams/Milwaukee-Bucks/16/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/16-milwaukee-bucks.png" style="height: 25px;"/> Milwaukee Bucks</a></li></ul>
# </div>
# <div style="float: left; width: 16em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Southeast Division</p>
# <ul class="primary-nav-col">
# <li><a href="/nba/teams/Atlanta-Hawks/1/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/1-atl-hawks.png" style="height: 25px;"/> Atlanta Hawks</a></li><li><a href="/nba/teams/Charlotte-Hornets/3/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/3-cha-hornets.png" style="height: 25px;"/> Charlotte Hornets</a></li><li><a href="/nba/teams/Miami-Heat/15/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/15-miami-heat.png" style="height: 25px;"/> Miami Heat</a></li><li><a href="/nba/teams/Orlando-Magic/21/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/21-orlando-magic.png" style="height: 25px;"/> Orlando Magic</a></li><li><a href="/nba/teams/Washington-Wizards/30/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/30-was-wizards.png" style="height: 25px;"/> Washington Wizards</a></li></ul>
# </div>
# <div style="float: left; width: 16em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Northwest Division</p>
# <ul class="primary-nav-col">
# <li><a href="/nba/teams/Denver-Nuggets/7/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/7-den-nuggets.png" style="height: 25px;"/> Denver Nuggets</a></li><li><a href="/nba/teams/Minnesota-Timberwolves/17/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/17-min-wolves.png" style="height: 25px;"/> Minnesota Timberwolves</a></li><li><a href="/nba/teams/Oklahoma-City-Thunder/33/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/33-okc-thunder.png" style="height: 25px;"/> Oklahoma City Thunder</a></li><li><a href="/nba/teams/Portland-Trail-Blazers/24/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/24-por-blazers.png" style="height: 25px;"/> Portland Trail Blazers</a></li><li><a href="/nba/teams/Utah-Jazz/29/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/29-utah-jazz.png" style="height: 25px;"/> Utah Jazz</a></li></ul>
# </div>
# <div style="float: left; width: 16em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Pacific Division</p>
# <ul class="primary-nav-col">
# <li><a href="/nba/teams/Golden-State-Warriors/9/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/9-golden-state.png" style="height: 25px;"/> Golden State Warriors</a></li><li><a href="/nba/teams/Los-Angeles-Clippers/12/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/12-la-clippers.png" style="height: 25px;"/> Los Angeles Clippers</a></li><li><a href="/nba/teams/Los-Angeles-Lakers/13/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/13-la-lakers.png" style="height: 25px;"/> Los Angeles Lakers</a></li><li><a href="/nba/teams/Phoenix-Suns/23/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/23-phx-suns.png" style="height: 25px;"/> Phoenix Suns</a></li><li><a href="/nba/teams/Sacramento-Kings/25/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/25-sac-kings.png" style="height: 25px;"/> Sacramento Kings</a></li></ul>
# </div>
# <div style="float: left; width: 16em;">
# <p style="padding-left: 5px; text-decoration: underline; font-size: 1.1em;">Southwest Division</p>
# <ul class="primary-nav-col">
# <li><a href="/nba/teams/Dallas-Mavericks/6/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/6-dallas-mavs.png" style="height: 25px;"/> Dallas Mavericks</a></li><li><a href="/nba/teams/Houston-Rockets/10/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/10-houston-rockets.png" style="height: 25px;"/> Houston Rockets</a></li><li><a href="/nba/teams/Memphis-Grizzlies/14/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/14-memphis-grizzli.png" style="height: 25px;"/> Memphis Grizzlies</a></li><li><a href="/nba/teams/New-Orleans-Pelicans/19/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/19-new-orleans-pel.png" style="height: 25px;"/> New Orleans Pelicans</a></li><li><a href="/nba/teams/San-Antonio-Spurs/26/Home"><img src="https://basketball.realgm.com/images/basketball/5.0/team_logos/nba/26-san-antonio-spu.png" style="height: 25px;"/> San Antonio Spurs</a></li></ul>
# </div>
# <div style="clear: both;"></div>
# </div>
# </li><li class="has-subnav">
# <a href="/nba/transactions/league">Transactions<span class="primary-nav-ddl-icon">▾</span></a>
# <div class="primary-nav-ddl">
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/transactions/league">Transactions</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/transactions/league">Transactions History</a></li><li style="float: left; margin-right: 1em;"><a href="/tradechecker">Trade Checker</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/transactions/composition">Roster Compositions</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/transactions/composition_search">Compositions Search</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/transactions/trade-deadline">Trade Deadline</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/player_tracker/trade">Trade Tracker</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/roster-turnover">Roster Turnover</a></li></ul>
# <div style="clear: both;"></div>
# <br/>
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/current_free_agents">Free Agency</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/current_free_agents">Current Free Agents</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/future_free_agents">Future Free Agents</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/player_tracker/free_agent">Free Agent Tracker</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/offseason">Offseason Recap</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/free_agent_options">Contract Options</a></li></ul>
# <div style="clear: both;"></div>
# <br/>
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/info/salary_cap">Salary Cap</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/info/salary_cap">Salary Cap History</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/info/minimum_scale">Minimum Scale</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/info/rookie_scale">Rookie Scale</a></li><li style="float: left; margin-right: 1em;"><a href="http://www.cbafaq.com/salarycap.htm" target="_blank">NBA Salary Cap FAQ</a></li></ul>
# </div>
# </li><li class="has-subnav">
# <a href="/nba/stats">Stats<span class="primary-nav-ddl-icon">▾</span></a>
# <div class="primary-nav-ddl">
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/stats">Player Stats</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/stats">Player Stats</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/stats/2026/Advanced_Stats/Qualified/points/All/desc/1/Regular_Season">Advanced Stats</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/stats/2026/Misc_Stats/Qualified/per/All/desc/1/Regular_Season">Misc. Stats</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/daily-leaders">Daily Leaders</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/individual-games">Individual Games</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/individual-seasons">Individual Seasons</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/stats/2026/Averages/Qualified/points/All/desc/1/Playoffs">Playoff Stats</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/stats/2026/Averages/Qualified/points/All/desc/1/Preseason">Preseason Stats</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/stats/2026/Averages/Qualified/points/All/desc/1/Summer_League">Summer League Stats</a></li></ul>
# <div style="clear: both;"></div>
# <br/>
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/team-stats">Team Stats</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/team-stats">Team Stats</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/team-stats/2026/Advanced_Stats/Team_Totals/Regular_Season/ediff/desc">Team Net Rating</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/team-stats/2026/Advanced_Stats/Team_Totals/Regular_Season/ortg/desc">Offensive Efficiency</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/team-stats/2026/Advanced_Stats/Team_Totals/Regular_Season/drtg/desc">Defensive Efficiency</a></li></ul>
# <div style="clear: both;"></div>
# </div>
# </li><li class="has-subnav">
# <a href="/nba/scores">Games<span class="primary-nav-ddl-icon">▾</span></a>
# <div class="primary-nav-ddl">
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/scores">Games</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/scores">Scores</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/schedules">Schedule</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/standings">Standings</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/venues">Venues</a></li></ul>
# <div style="clear: both;"></div>
# </div>
# </li><li class="has-subnav">
# <a href="/nba/players">Players<span class="primary-nav-ddl-icon">▾</span></a>
# <div class="primary-nav-ddl">
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/players">Players</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/players">Current Players</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/depth-charts">Depth Charts</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/birth-cities">Birth Cities</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/birth-countries">Birth Countries</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/birth-dates">Birth Dates</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/players-abroad">NBA Players Abroad</a></li></ul>
# <div style="clear: both;"></div>
# <br/>
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/awards">Awards</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/awards/by-season">By Season</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/awards/by-type">By Type</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/awards/by-player">By Player</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/awards/ballot">Ballot Generator</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/awards/top_75">NBA's Top 75</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/hall-of-fame">Hall of Fame</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/retired-numbers">Retired Jerseys</a></li></ul>
# <div style="clear: both;"></div>
# <br/>
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/staff-members">Staff Members</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/staff-members/20/Head-Coach/Current">Head Coaches</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/staff-members/16/General-Manager/Current">General Managers</a></li></ul>
# <div style="clear: both;"></div>
# <br/>
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/agent-client-list">Agents</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/agent-client-list">Agent Client Lists</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/agent-relationships">Agent Relationships</a></li></ul>
# <div style="clear: both;"></div>
# </div>
# </li><li class="has-subnav">
# <a href="/nba/draft">NBA Draft<span class="primary-nav-ddl-icon">▾</span></a>
# <div class="primary-nav-ddl">
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/draft/future_drafts/team">Future Draft Picks</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/draft/future_drafts/team">Team Summary</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/future_drafts/yearly">Yearly Summary</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/future_drafts/detailed">Pick Details</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/future_drafts/tradeable">Tradeable Picks</a></li></ul>
# <div style="clear: both;"></div>
# <br/>
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/draft/draft_simulator">NBA Draft Tools</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/draft/draft_simulator">Mock Draft Simulator</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/lottery_simulator">Lottery Simulator</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/prospects/stats">Prospect Stats</a></li></ul>
# <div style="clear: both;"></div>
# <br/>
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/draft/past-drafts">NBA Draft History</a></p>
# <ul class="primary-nav-col">
# <li style="float: left; margin-right: 1em;"><a href="/nba/draft/past-drafts">Past Drafts</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/teams/Atlanta-Hawks/1/Draft_History/Historical">Team Draft History</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/draft-rights">Draft Rights</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/lottery_winners">Lottery Winners</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/lottery_results">Lottery History</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/lottery_results/by_team">Team Lottery History</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/search">NBA Draft Search</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/early_entry/by_year">Early Entrants</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft/special_events">Special Events</a></li></ul>
# <div style="clear: both;"></div>
# </div>
# </li><li class="has-subnav">
# <a href="/nba/events">Events<span class="primary-nav-ddl-icon">▾</span></a>
# <div class="primary-nav-ddl">
# <p style="text-decoration: underline; font-size: 1.1em;"><a href="/nba/events">Events</a></p><ul>
# <li style="float: left; margin-right: 1em;"><a href="/nba/summer">Summer League</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/preseason">Preseason</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/regular_season/history">Regular Season</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/nba-cup">NBA Cup</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/allstar">All-Star Weekend</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/playoffs">Playoffs</a></li><li style="float: left; margin-right: 1em;"><a href="/nba/draft">NBA Draft</a></li></ul>
# </div>
# <div style="clear: both;"></div>
# </li><li><a href="https://www.vividseats.com/nba-basketball/?wsUser=958" target="_blank">Tickets</a></li>
# <li><a href="/wnba">WNBA</a></li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# <div class="large_header_helper" id="header_helper"></div>
# <div id="StickyLeft" style="z-index: 9;"></div>
# <div class="main-container">
# <div class="main wrapper clearfix container" style="position: relative;">
# <div class="second-level-nav-container">
# <nav class="container" id="second-level-nav" role="navigation">
# <ul class="level-1">
# <li style="border-right: 1px solid #BCBCBC; margin-right: 0.3em;"><a href="/nba/events"><span>Events</span></a></li><li><a href="/nba/draft"><span>NBA Draft</span></a></li><li><a href="/nba/draft/news"><span>News</span></a></li><li><a href="/nba/draft/prospects/stats"><span>Prospects</span></a></li><li class="has-subnav">
# <a class="selected" href="/nba/draft/future_drafts/team"><span class="down">Future Drafts</span></a>
# <ul class="level-2">
# <li><a class="selected" href="/nba/draft/future_drafts/team">Team Summary</a></li><li><a href="/nba/draft/future_drafts/yearly">Yearly Summary</a></li><li><a href="/nba/draft/future_drafts/detailed">Pick Details</a></li><li><a "="" href="/nba/draft/future_drafts/tradeable">Tradeable Picks</a></li></ul>
# </li><li class="has-subnav">
# <a href="/nba/draft/past-drafts"><span class="down">Draft History</span></a>
# <ul class="level-2">
# <li><a href="/nba/draft/past-drafts">Past Drafts</a></li><li><a href="/nba/draft/draft-rights">Draft Rights</a></li><li><a href="/nba/draft/search">NBA Draft Search</a></li><li><a href="/nba/draft/aba-dispersal">ABA Dispersal</a></li><li><a href="/nba/draft/dispersal-draft">Dispersal Drafts</a></li><li><a href="/nba/draft/expansion-draft">Expansion Drafts</a></li><li><a href="/nba/draft/hardship-draft">Hardship Draft</a></li><li><a href="/nba/draft/supplemental-draft">Supplemental Draft</a></li></ul>
# </li><li class="has-subnav">
# <a href="/nba/draft/early_entry/by_year"><span class="down">Early Entry</span></a>
# <ul class="level-2">
# <li><a href="/nba/draft/early_entry/by_year">By Year</a></li><li><a href="/nba/draft/early_entry/by_type">By Type</a></li></ul>
# </li><li class="has-subnav">
# <a href="/nba/draft/lottery_results"><span class="down">Lottery</span></a>
# <ul class="level-2">
# <li><a href="/nba/draft/lottery_results">Yearly History</a></li><li><a href="/nba/draft/lottery_results/by_team">Team History</a></li><li><a href="/nba/draft/lottery_winners">Lottery Winners</a></li><li><a href="/nba/draft/lottery_simulator">Lotto Simulator</a></li></ul>
# </li><li><a href="/nba/draft/draft_simulator"><span>Draft Simulator</span></a></li><li><a href="/nba/draft/special_events"><span>Special Events</span></a></li><li><a href="https://forums.realgm.com/boards/viewforum.php?f=3"><span>Forums</span></a></li></ul>
# </nav>
# </div>
# <div class="interior-page">
# <h1 class="page_title">NBA Future Draft Picks By Team
# </h1>
# <h2>Atlanta Hawks Future NBA Draft Picks</h2><table class="table table-striped table-hover table-bordered table-compact">
# <thead>
# <tr>
# <th class="nosort" style="width: 50px; text-align: left;">Year</th>
# <th class="nosort" style="width: 48%; text-align: left;">First Round</th>
# <th class="nosort" style="width: 48%; text-align: left;">Second Round</th>
# </tr>
# </thead>
# <tbody><tr>
# <td data-th="Year" rel="2026" style="vertical-align: top; font-weight: bold;"><p>2026</p></td>
# <td data-th="First Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>More favorable of (i) less favorable of ATL and SAN and (ii) less favorable of (a) CLE and (b) more favorable of UTH 1-8 and MIN</strong> <small>[or (ii) CLE if UTH not conveyable]</small> <strong>then less favorable of (i) and (ii) to CLE; <br/></strong><strong>more favorable of ATL and SAN to SAN</strong> <br><small>(via UTH swap for MIN; via UTH swap of UTH or MIN for CLE; via SAN swap for ATL; via ATL swap of ATL or SAN for CLE, UTH or MIN)</small>;</br></p>
# <p>More favorable of NOP and MIL <small>(via NOP swap for MIL)</small></p><strong><p><span style="color: green;">2</span></p></strong></td>
# <td data-th="Second Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>To BRK</strong> <small>(via GOS)</small>;</p>
# <p>Less favorable of (i) BOS and (ii) more favorable of IND and MIA <small>(via MIA to IND to MIL; via MEM swap of IND or MIA for BOS; via BOS to ATL)</small></p><strong><p><span style="color: green;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2027" style="vertical-align: top; font-weight: bold;"><p>2027</p></td>
# <td data-th="First Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>To SAN</strong>;</p>
# <p>Less favorable of MIL and NOP if either or both 5-30 <small>(via NOP)</small></p><strong><p><span style="color: gold;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>To POR</strong> <small>(via BOS to MEM)</small></p><strong><p><span style="color: red;">0</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2028" style="vertical-align: top; font-weight: bold;"><p>2028</p></td>
# <td data-th="First Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>More favorable of (i) ATL and (ii) less favorable of UTH and CLE then least favorable of all to CLE</strong> <small>(via UTH swap for CLE; via ATL swap for UTH or CLE)</small></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>To BRK</strong> <small>(via GOS)</small></p><strong><p><span style="color: red;">0</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2029" style="vertical-align: top; font-weight: bold;"><p>2029</p></td>
# <td data-th="First Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>To OKC</strong>;</p>
# <p>CLE</p><strong><p><span style="color: green;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2030" style="vertical-align: top; font-weight: bold;"><p>2030</p></td>
# <td data-th="First Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2031" style="vertical-align: top; font-weight: bold;"><p>2031</p></td>
# <td data-th="First Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>Own or swap for HOU 31-55</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2032" style="vertical-align: top; font-weight: bold;"><p>2032</p></td>
# <td data-th="First Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Atlanta Hawks" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# </tr>
# </tbody></table>
# <h2>Boston Celtics Future NBA Draft Picks</h2><table class="table table-striped table-hover table-bordered table-compact">
# <thead>
# <tr>
# <th class="nosort" style="width: 50px; text-align: left;">Year</th>
# <th class="nosort" style="width: 48%; text-align: left;">First Round</th>
# <th class="nosort" style="width: 48%; text-align: left;">Second Round</th>
# </tr>
# </thead>
# <tbody><tr>
# <td data-th="Year" rel="2026" style="vertical-align: top; font-weight: bold;"><p>2026</p></td>
# <td data-th="First Round" rel="Boston Celtics" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Boston Celtics" style="vertical-align: top;"><p><strong>Less favorable of (i) BOS and (ii) more favorable of IND and MIA to ATL then most favorable of all to MEM or to BRK</strong> <small>[MEM can swap this pick for LAC; LAC then conveyed to HOU which then conveyed to BRK] (via MIA to IND to MIL; via MEM swap of IND or MIA for BOS; via BOS to ATL; via LAC to HOU to BRK)</small>; <br><br>Most favorable of MIN, NYK, NOP and POR <small>(via MIN to NYK; via NOP to POR to NOP; via POR to DET to BOS)</small>; <br><br>Most favorable of ORL, DET and MIL <small>(via MIL to ORL; via DET to LAC to ORL)</small></br></br></br></br></p><strong><p><span style="color: green;">2</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2027" style="vertical-align: top; font-weight: bold;"><p>2027</p></td>
# ...
# <td data-th="Second Round" rel="Toronto Raptors" style="vertical-align: top;"><p><strong>To NOP</strong></p><strong><p><span style="color: red;">0</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2032" style="vertical-align: top; font-weight: bold;"><p>2032</p></td>
# <td data-th="First Round" rel="Toronto Raptors" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Toronto Raptors" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# </tr>
# </tbody></table>
# <h2>Utah Jazz Future NBA Draft Picks</h2><table class="table table-striped table-hover table-bordered table-compact">
# <thead>
# <tr>
# <th class="nosort" style="width: 50px; text-align: left;">Year</th>
# <th class="nosort" style="width: 48%; text-align: left;">First Round</th>
# <th class="nosort" style="width: 48%; text-align: left;">Second Round</th>
# </tr>
# </thead>
# <tbody><tr>
# <td data-th="Year" rel="2026" style="vertical-align: top; font-weight: bold;"><p>2026</p></td>
# <td data-th="First Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>Most / more favorable of UTH 1-8, MIN and CLE; <br/></strong><strong>less favorable of UTH 1-8 and MIN </strong><small>[or MIN if UTH not conveyable] </small><strong>to MIN;<br/></strong><strong>less favorable of (i) CLE and (ii) more favorable of UTH 1-8 and MIN</strong> <small>[or CLE if UTH not conveyable]</small> <strong>to CLE</strong> <small>[CLE may convey to ATL]</small><strong>; <br/></strong><strong>UTH 9-30 to OKC</strong> <br/><small>(via UTH swap for MIN; via UTH swap of UTH or MIN for CLE)</small></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>31-55 to SAN; <br/>56-60 to MIL</strong> <small>(via MIN to SAN)</small></p><strong><p><span style="color: red;">0</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2027" style="vertical-align: top; font-weight: bold;"><p>2027</p></td>
# <td data-th="First Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>Two most favorable of UTH, CLE and MIN then other to PHX</strong> <small>(via CLE and MIN to UTH)</small>; <br/><br/>LAL 5-30</p><strong><p><span style="color: green;">2</span> + <span style="color: gold;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>To IND</strong> <small>(via CLE)</small>; <br/><br/>LAC <small>(via ATL to LAC)</small>; <br/><br/>LAL <small>if LAL does not convey 1st round pick to UTH in 2027</small></p><strong><p><span style="color: green;">1</span> + <span style="color: gold;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2028" style="vertical-align: top; font-weight: bold;"><p>2028</p></td>
# <td data-th="First Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>Own or swap for CLE</strong> <small>[CLE may convey UTH to ATL]</small></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>To OKC</strong>; <br/><br/>Least favorable of (i) DET 31-55, (ii) less favorable of CHA and LAC <small>(via CHA to DAL to DET)</small>, (iii) MIA <small>if DAL conveys 1st round pick to CHA in 2027 (via SAN to DAL to DET)</small> and (iv) NYK <small>(via DET)</small></p><strong><p><span style="color: green;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2029" style="vertical-align: top; font-weight: bold;"><p>2029</p></td>
# <td data-th="First Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>Most / two most favorable of UTH, CLE and MIN 6-30 then other to CHA</strong> <small>(via CLE and MIN to UTH to PHX)</small></p><strong><p><span style="color: green;">1</span> + <span style="color: gold;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>Own</strong>; <br/><br/>MIN <small>if MIN does not convey 1st round pick to UTH in 2029</small></p><strong><p><span style="color: green;">1</span> + <span style="color: gold;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2030" style="vertical-align: top; font-weight: bold;"><p>2030</p></td>
# <td data-th="First Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>Less favorable of UTH and LAC then other to CHA</strong> <small>(via LAC to UTH)</small></p><strong><p><span style="color: green;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2031" style="vertical-align: top; font-weight: bold;"><p>2031</p></td>
# <td data-th="First Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>Own</strong>; <br/><br/>PHX</p><strong><p><span style="color: green;">2</span></p></strong></td>
# <td data-th="Second Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2032" style="vertical-align: top; font-weight: bold;"><p>2032</p></td>
# <td data-th="First Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Utah Jazz" style="vertical-align: top;"><p><strong>To WAS</strong></p><strong><p><span style="color: red;">0</span></p></strong></td>
# </tr>
# </tbody></table>
# <h2>Washington Wizards Future NBA Draft Picks</h2><table class="table table-striped table-hover table-bordered table-compact">
# <thead>
# <tr>
# <th class="nosort" style="width: 50px; text-align: left;">Year</th>
# <th class="nosort" style="width: 48%; text-align: left;">First Round</th>
# <th class="nosort" style="width: 48%; text-align: left;">Second Round</th>
# </tr>
# </thead>
# <tbody><tr>
# <td data-th="Year" rel="2026" style="vertical-align: top; font-weight: bold;"><p>2026</p></td>
# <td data-th="First Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>1-8 Own or swap for PHX; <br/>two most favorable of (i) less favorable of WAS 1-8 and PHX </strong><small>[or (ii) PHX if WAS not conveyable]</small><strong>, (ii) MEM and (iii) ORL to MEM then least favorable of all to CHA</strong> <br/><small>(via WAS swap for PHX; via MEM swap of ORL for PHX or WAS; via MEM swap for PHX, WAS or ORL; via PHX to CHA)</small><strong>; <br/>WAS 9-30 to NYK</strong> <small>(via HOU to OKC)</small>; <br/><br/>Least / less favorable of OKC, HOU 5-30 and LAC <small>(via OKC to PHL)</small></p><strong><p><span style="color: green;">1</span> + <span style="color: gold;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>To NYK</strong> <small>if WAS does not convey 1st round pick to NYK in 2026 (via HOU to OKC)</small>; <br/><br/>Less favorable of (i) more favorable of MIN and NYK and (ii) more favorable of NOP and POR <small>(via MIN to NYK; via NOP to POR to NOP; via POR to DET to WAS)</small>; <br/><br/>Least favorable of OKC, DAL and PHL <small>(via OKC to MIA to SAN)</small>; <br/><br/>PHX</p><strong><p><span style="color: green;">3</span> + <span style="color: gold;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2027" style="vertical-align: top; font-weight: bold;"><p>2027</p></td>
# <td data-th="First Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>To NYK</strong> <small>if WAS does not convey 1st round pick to NYK in 2026 (via HOU to OKC)</small>; <br/><br/>More favorable of BRK and DAL <small>(via DAL to BRK to DET; via DET to WAS)</small>; <br/><br/>CHI <small>(in separate, protected conveyances; via WAS to NOP)</small>; <br/><br/>Less favorable of GOS and PHX</p><strong><p><span style="color: green;">3</span> + <span style="color: gold;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2028" style="vertical-align: top; font-weight: bold;"><p>2028</p></td>
# <td data-th="First Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>More favorable of (i) more favorable of (a) WAS and (b) least / less favorable of BRK, PHL 9-30</strong><small> if PHL conveys 1st round pick to OKC in 2026,</small> <strong>and PHX and (ii) less favorable of MIL and POR 1-14</strong> <small>if POR has not conveyed 1st round pick to CHI by 2027 [or (ii) MIL if POR not conveyable]</small> <strong>then less favorable of (i) and (ii) to MIL;</strong> <br/><small>or</small> <strong>More favorable of (i) more favorable of (a) WAS and (b) least / less favorable of BRK, PHL 9-30</strong><small> if PHL conveys 1st round pick to OKC in 2026,</small> <strong>and PHX and (ii) less favorable of MIL and POR</strong> <small>if POR has conveyed 1st round pick to CHI by 2027,</small> <strong>then less favorable of (i) and (ii) to MIL; <br/></strong><strong>least favorable of WAS, PHL 9-30</strong><small> if PHL does not convey 1st round pick to BRK in 2027 and if PHL has conveyed 1st round pick to OKC by 2026<strong>,</strong></small><strong> BRK and PHX to PHX</strong><br/><small>(via POR swap for MIL; via BRK swap of BRK or PHL for PHX; via WAS swap for PHX, BRK or PHL; via WAS swap of WAS, BRK, PHL or PHX for MIL or POR)</small></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>Less favorable of WAS and LAL then other to ORL</strong> <small>(via WAS to LAL to ORL; via LAL to WAS)</small>; <br/><br/>DEN 34-60 <small>(via SAN to SAC)</small></p><strong><p><span style="color: green;">1</span> + <span style="color: gold;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2029" style="vertical-align: top; font-weight: bold;"><p>2029</p></td>
# <td data-th="First Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>Own</strong>; <br/><br/>Second most favorable of POR, BOS and MIL <small>(via BOS to POR; via MIL to POR; via POR to WAS)</small></p><strong><p><span style="color: green;">2</span></p></strong></td>
# <td data-th="Second Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>More favorable of WAS and IND to IND then other to POR</strong> <small>(via IND to NYK)</small>; <br/><br/>HOU <small>(via OKC)</small>; <br/><br/>LAL</p><strong><p><span style="color: green;">2</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2030" style="vertical-align: top; font-weight: bold;"><p>2030</p></td>
# <td data-th="First Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>More favorable of WAS and PHX; <br/>more favorable of (i) MEM and (ii) less favorable of WAS and PHX to MEM then least favorable of all to PHX</strong> <br/><small>(via WAS swap for PHX; via MEM swap for WAS or PHX)</small>; <br/><br/>GOS 21-30</p><strong><p><span style="color: green;">1</span> + <span style="color: gold;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>To PHL</strong>; <br/><br/>GOS <small>if GOS does not convey 1st round pick to WAS in 2030</small>; <br/><br/>Less favorable of PHX and POR</p><strong><p><span style="color: green;">1</span> + <span style="color: gold;">1</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2031" style="vertical-align: top; font-weight: bold;"><p>2031</p></td>
# <td data-th="First Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>Own</strong>; <br/><br/>More favorable of MIA and IND <small>(via MIA swap for IND; via UTH)</small></p><strong><p><span style="color: green;">2</span></p></strong></td>
# </tr>
# <tr>
# <td data-th="Year" rel="2032" style="vertical-align: top; font-weight: bold;"><p>2032</p></td>
# <td data-th="First Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>Own</strong></p><strong><p><span style="color: green;">1</span></p></strong></td>
# <td data-th="Second Round" rel="Washington Wizards" style="vertical-align: top;"><p><strong>Own</strong>; <br/><br/>UTH</p><strong><p><span style="color: green;">2</span></p></strong></td>
# </tr>
# </tbody></table>
# <div style="clear: both;"></div>
# <script src="//widget.sellwild.com/realgm/realgm-realgm.js"></script>
# <div style="margin-top: 1em;">
# <sellwild-widget></sellwild-widget>
# </div>
# </div>
# <div style="clear: both;"></div>
# <input name="pageid" type="hidden" value="nba_draft_future_summary_by_team">
# </input></div> <!-- #main -->
# </div> <!-- #main-container -->
# <footer class="container wrapper">
# <div class="about-us-container">
# <div class="social clearfix">
# <div style="text-align: center;">
# <h3>Follow Us</h3>
# <a href="https://realgm.m-pages.com/ug2pDT/sign-up" style="margin-right: 0.5em;" target="_blank"><img alt="RealGM Heads Up Newsletter" src="https://basketball.realgm.com/images/icons/social-mail.png" style="height: 32px;" title="RealGM Heads Up Newsletter"/></a>
# <a href="https://x.com/RealGM" style="margin-right: 0.5em;" target="_blank"><img alt="Follow RealGM on X" src="https://basketball.realgm.com/images/icons/social-x.png" style="height: 32px;" title="Follow RealGM on X"/></a>
# <a href="https://bsky.app/profile/realgmnba.bsky.social" style="margin-right: 0.5em;" target="_blank"><img alt="Follow RealGM on Bluesky" src="https://basketball.realgm.com/images/icons/social-bluesky.png" style="height: 32px;" title="Follow RealGM on Bluesky"/></a>
# <a href="https://www.instagram.com/realgmnba" style="margin-right: 0.5em;" target="_blank"><img alt="Follow RealGM on Instagram" src="https://basketball.realgm.com/images/icons/social-insta.png" style="height: 32px;" title="Follow RealGM on Instagram"/></a>
# </div> </div>
# </div>
# <div class="footer-logo-container wrapper clearfix">
# <a alt="RealGM" class="footer-logo mobile-only" href="/"></a>
# <div class="sports-links-container">
# <div class="list-column">
# <div class="links">
# <a class="desktop" href="https://basketball.realgm.com/nba">NBA</a>
# <a class="desktop" href="https://basketball.realgm.com/gleague">G League</a>
# <a class="desktop" href="https://basketball.realgm.com/ncaa">NCAA</a>
# <a class="desktop" href="https://basketball.realgm.com/international">International</a>
# <a class="desktop" href="https://basketball.realgm.com/national">National</a>
# <a class="desktop" href="https://basketball.realgm.com/highschool">High School</a>
# <a class="desktop" href="https://basketball.realgm.com/wnba">WNBA</a>
# <br class="desktop"/>
# <a class="mobile" href="https://basketball.realgm.com/" target="_blank">Basketball</a>
# <a href="https://football.realgm.com/" target="_blank">Football</a>
# <a href="https://baseball.realgm.com/" target="_blank">Baseball</a>
# <a href="https://hockey.realgm.com/" target="_blank">Hockey</a>
# <a href="https://soccer.realgm.com/" target="_blank">Soccer</a>
# <br class="mobile-formatting"/>
# <a href="/info/contact-us">Contact Us</a>
# <a href="/info/about-us">About Us</a>
# <a href="/info/contact-us/advertising">Advertising</a>
# <a href="/info/privacy-policy">Privacy Policy</a>
# <a href="/info/terms-of-use">Terms of Use</a>
# </div>
# </div>
# </div>
# </div>
# <p class="copyright">All content © 2000-2025 RealGM, L.L.C. All rights reserved.</p>
# <div style="height: 7em;"> </div>
# </footer>
# </div> <!-- #site-takeover -->
# <script src="/js/vendor/jquery.hoverIntent.min.js"></script>
# <script src="/js/main-5.js"></script>
# <script src="/js/plugins.js?v3"></script>
# </body>
# </html>

# %%
# Extract and display the Atlanta Hawks draft pick table using a more robust approach
atlanta_table = None
for h2 in soup.find_all('h2'):
    if 'Atlanta Hawks' in h2.text:
        next_table = h2.find_next('table')
        if next_table:
            atlanta_table = next_table
            break

if atlanta_table:
    # Extract header
    headers = [th.text.strip() for th in atlanta_table.find_all('th')]
    print('Headers:', headers)
    # Extract rows
    for row in atlanta_table.find_all('tr')[1:]:
        cols = [td.get_text(separator=' ', strip=True) for td in row.find_all('td')]
        print(cols)
else:
    print('Atlanta Hawks table not found.')
# Out:
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'More favorable of (i) less favorable of ATL and SAN and (ii) less favorable of (a) CLE and (b) more favorable of UTH 1-8 and MIN [or (ii) CLE if UTH not conveyable] then less favorable of (i) and (ii) to CLE; more favorable of ATL and SAN to SAN (via UTH swap for MIN; via UTH swap of UTH or MIN for CLE; via SAN swap for ATL; via ATL swap of ATL or SAN for CLE, UTH or MIN) ; More favorable of NOP and MIL (via NOP swap for MIL) 2', 'To BRK (via GOS) ; Less favorable of (i) BOS and (ii) more favorable of IND and MIA (via MIA to IND to MIL; via MEM swap of IND or MIA for BOS; via BOS to ATL) 1']
# ['2027', 'To SAN ; Less favorable of MIL and NOP if either or both 5-30 (via NOP) 1', 'To POR (via BOS to MEM) 0']
# ['2028', 'More favorable of (i) ATL and (ii) less favorable of UTH and CLE then least favorable of all to CLE (via UTH swap for CLE; via ATL swap for UTH or CLE) 1', 'To BRK (via GOS) 0']
# ['2029', 'Own 1', 'To OKC ; CLE 1']
# ['2030', 'Own 1', 'Own 1']
# ['2031', 'Own 1', 'Own or swap for HOU 31-55 1']
# ['2032', 'Own 1', 'Own 1']

# %%
# Extract and display draft pick tables for all NBA teams
team_tables = []
for h2 in soup.find_all('h2'):
    team_name = h2.text.strip()
    next_table = h2.find_next('table')
    if next_table:
        # Extract header
        headers = [th.text.strip() for th in next_table.find_all('th')]
        # Extract rows
        rows = []
        for row in next_table.find_all('tr')[1:]:
            cols = [td.get_text(separator=' ', strip=True) for td in row.find_all('td')]
            rows.append(cols)
        team_tables.append({'team': team_name, 'headers': headers, 'rows': rows})

# Print summary for all teams
for team_info in team_tables:
    print(f"Team: {team_info['team']}")
    print('Headers:', team_info['headers'])
    for row in team_info['rows']:
        print(row)
    print('-' * 40)
# Out:
# Team: Atlanta Hawks Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'More favorable of (i) less favorable of ATL and SAN and (ii) less favorable of (a) CLE and (b) more favorable of UTH 1-8 and MIN [or (ii) CLE if UTH not conveyable] then less favorable of (i) and (ii) to CLE; more favorable of ATL and SAN to SAN (via UTH swap for MIN; via UTH swap of UTH or MIN for CLE; via SAN swap for ATL; via ATL swap of ATL or SAN for CLE, UTH or MIN) ; More favorable of NOP and MIL (via NOP swap for MIL) 2', 'To BRK (via GOS) ; Less favorable of (i) BOS and (ii) more favorable of IND and MIA (via MIA to IND to MIL; via MEM swap of IND or MIA for BOS; via BOS to ATL) 1']
# ['2027', 'To SAN ; Less favorable of MIL and NOP if either or both 5-30 (via NOP) 1', 'To POR (via BOS to MEM) 0']
# ['2028', 'More favorable of (i) ATL and (ii) less favorable of UTH and CLE then least favorable of all to CLE (via UTH swap for CLE; via ATL swap for UTH or CLE) 1', 'To BRK (via GOS) 0']
# ['2029', 'Own 1', 'To OKC ; CLE 1']
# ['2030', 'Own 1', 'Own 1']
# ['2031', 'Own 1', 'Own or swap for HOU 31-55 1']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Boston Celtics Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own 1', 'Less favorable of (i) BOS and (ii) more favorable of IND and MIA to ATL then most favorable of all to MEM or to BRK [MEM can swap this pick for LAC; LAC then conveyed to HOU which then conveyed to BRK] (via MIA to IND to MIL; via MEM swap of IND or MIA for BOS; via BOS to ATL; via LAC to HOU to BRK) ; Most favorable of MIN, NYK, NOP and POR (via MIN to NYK; via NOP to POR to NOP; via POR to DET to BOS) ; Most favorable of ORL, DET and MIL (via MIL to ORL; via DET to LAC to ORL) 2']
# ['2027', 'Own 1', 'More favorable of BOS and ORL then other to ORL (via ORL) 1']
# ['2028', '1 Own; 2-30 Own or SAN (via SAN swap for BOS) 1', '31-45 to SAN if BOS 1 in 2028 ; 46-60 to NYK (via ORL to PHX) 1']
# ['2029', 'Most and least favorable of BOS, POR and MIL to POR; second most favorable to WAS (via BOS to POR; via MIL to POR; via POR to WAS) 0', 'To OKC 0']
# ['2030', 'Own 1', 'To BRK (via HOU) 0']
# ['2031', 'Own 1', 'Own ; CLE (via ATL) ; HOU 56-60 2 + 1']
# ['2032', 'Frozen (through 2027-28) 1', 'Own 1']
# ----------------------------------------
# Team: Brooklyn Nets Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own (via HOU) 1', 'Own ; ATL (via GOS) ; Less favorable of (i) LAC and (ii) most favorable of BOS, IND and MIA (via MIA to IND to MIL; via MEM swap of IND or MIA for BOS; via MEM swap of BOS, IND or MIA for LAC; via LAC to HOU to BRK) 3']
# ['2027', 'Own or HOU (via HOU swap for BRK) ; NYK 2', 'More favorable of BRK and DAL to WAS then other to DET (via DAL to BRK to DET; via DET to WAS) ; LAL if LAL conveys 1st round pick to UTH in 2027 1']
# ['2028', 'If (i) PHL 9-30 , if PHL conveys 1st round pick to OKC in 2026, is third most favorable and (ii) NYK is most or second most favorable of BRK, PHL 9-30 if conveyable , PHX and NYK, then most and third most favorable to BRK; or most / two most favorable to BRK in all other scenarios ; least favorable of BRK, PHX and NYK to NYK if NYK and / or if PHL 9-30 , if conveyable, is less favorable than BRK and PHX; or second most favorable of BRK, PHX and NYK to NYK in all other scenarios ; more favorable of (i) WAS and (ii) least / less favorable of BRK, PHL 9-30 if conveyable, and PHX to WAS then least favorable of all to PHX [WAS can then swap with MIL] (via BRK swap of BRK or PHL for PHX; via BRK swap of BRK or PHX for NYK; via WAS swap for PHX, BRK or PHL) 1 + 1', 'Own ; ATL (via GOS) ; MEM (via PHX) ; PHL if PHL does not convey 1st round pick to BRK in 2028 3 + 1']
# ['2029', 'Own ; Least favorable of DAL, PHX and HOU (via DAL and PHX to BRK; via DAL or PHX to HOU; via HOU swap for DAL or PHX) ; NYK 3', 'Own ; DAL; GOS; MEM (via PHX) 4']
# ['2030', 'Own 1', 'Own ; BOS (via HOU) ; DAL (via BOS to MEM) ; LAL 4']
# ['2031', 'Own ; NYK 2', 'Own ; LAL 2']
# ['2032', 'Own ; DEN 2', 'Own 1']
# ----------------------------------------
# Team: Charlotte Hornets Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own ; Least favorable of PHX, WAS 1-8, ORL and MEM (via WAS swap for PHX; via MEM swap of ORL for PHX or WAS; via MEM swap for PHX, WAS or ORL; via PHX to CHA) 2', '31-55 to SAC; 56-60 to DET (via NYK to ATL to SAN to SAC) ; More favorable of DEN and GOS (via DEN to PHX; via GOS to ATL to OKC to NYK) 1']
# ['2027', 'Own ; DAL 3-30; MIA 15-30 1 + 2', 'To SAC if SAN 17-30 in 2027 or to OKC if SAN 1-16 in 2027 (via NYK to ATL to SAN to SAC) ; More favorable of POR and NOP (via POR) 1']
# ['2028', 'Own ; MIA if not already settled 1 + 1', 'More favorable of CHA and LAC then other to DET [DET may convey to UTH] (via CHA to DAL) ; MIA if DAL does not convey 1st round pick to CHA in 2027 (via SAN to DAL) 1 + 1']
# ['2029', 'Own ; Least / less favorable of UTH, CLE and MIN 6-30 (via CLE and MIN to UTH to PHX) 2', 'Own ; DEN if DEN has conveyed a first potential 1st round pick to OKC by 2029 1 + 1']
# ['2030', 'Own 1', 'Own ; More favorable of UTH and LAC (via UTH) 2']
# ['2031', 'Own 1', 'Own ; DEN (via PHX) ; MIL; NYK; PHX 5']
# ['2032', 'Own 1', 'Own ; MIL 2']
# ----------------------------------------
# Team: Chicago Bulls Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own ; POR 15-30 1 + 1', 'To HOU (via WAS) 0']
# ['2027', 'Own ; POR 15-30 if not already settled 1 + 1', 'To WAS (in separate, protected conveyances; via WAS to NOP) 0']
# ['2028', 'Own ; POR 15-30 if not already settled 1 + 1', 'Own ; POR if POR has not conveyed 1st round pick to CHI by 2028 1 + 1']
# ['2029', 'Own 1', 'Own 1']
# ['2030', 'Own 1', 'Own 1']
# ['2031', 'Own 1', 'Own 1']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Cleveland Cavaliers Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Less favorable of (i) less favorable of (a) CLE and (b) more favorable of UTH 1-8 and MIN [or (i) CLE if UTH not conveyable] and (ii) less favorable of ATL and SAN then more favorable of (i) and (ii) to ATL; most / more favorable of CLE, MIN and UTH 1-8 to UTH (via UTH swap for MIN; via UTH swap of UTH or MIN for CLE; via SAN swap for ATL; via ATL swap of ATL or SAN for CLE, UTH or MIN) 1', 'Own 1']
# ['2027', 'Two most favorable of CLE, MIN and UTH to UTH then other to PHX (via CLE and MIN to UTH) 0', 'To MIN (via ATL) ; DEN 1']
# ['2028', 'Least favorable of CLE, UTH and ATL; more favorable of CLE and UTH to UTH; more favorable of (i) ATL and (ii) less favorable of CLE and UTH to ATL (via UTH swap for CLE; via ATL swap for CLE or UTH) 1', 'Own 1']
# ['2029', 'Most / two most favorable of CLE, MIN 6-30 and UTH to UTH then other to CHA (via CLE and MIN to UTH to PHX) 0', 'To ATL 0']
# ['2030', 'Own 1', 'To SAN 0']
# ['2031', 'Own 1', 'To BOS (via ATL) 0']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Dallas Mavericks Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own 1', 'Most favorable of DAL, OKC and PHL to OKC; second most favorable to PHX and least favorable to WAS (via OKC to HOU to PHX; via OKC to MIA to SAN to WAS) 0']
# ['2027', '1-2 Own; 3-30 to CHA 1', 'More favorable of DAL and BRK to WAS then other to DET (via DET to WAS; via DAL to BRK to DET) 0']
# ['2028', 'Own or OKC (via OKC swap for DAL) 1', 'To IND (via SAC) 0']
# ['2029', 'Two most favorable of DAL, HOU and PHX to HOU then other to BRK (via DAL and PHX to BRK; via DAL or PHX to HOU; via HOU swap for DAL or PHX) ; LAL 1', 'To BRK 0']
# ['2030', 'Own or SAN (via SAN swap for DAL) ; less favorable of (i) MIN 2-30 and (ii) more favorable of DAL and SAN [or MIN if MIN not conveyable] to MIN then most / more favorable of all to SAN (via SAN swap for DAL; via SAN swap of SAN or DAL for MIN) 1', 'To BRK (via BOS to MEM) ; PHL 1']
# ['2031', 'Own 1', 'To DET (via PHL) 0']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Denver Nuggets Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own 1', 'More favorable of DEN and GOS to CHA then other to MIN (via DEN to PHX to CHA; via GOS to ATL to OKC to NYK to CHA; via CHA to PHX to MIN) 0']
# ['2027', '1-5 Own; 6-30 to OKC or to LAC [OKC can swap OKC or DEN for LAC] 1', 'To CLE 0']
# ['2028', '1-5 Own; 6-30 to OKC if not already settled 1', '31-33 Own; 34-60 to WAS (via SAN to SAC) 1']
# ['2029', '1-5 Own; 6-30 to OKC if not already settled ; or 1-5 Own; 6-30 to OKC if DEN has conveyed a first potential 1st round pick to OKC by 2027 1', 'To OKC if DEN has not conveyed a first potential 1st round pick to OKC by 2029 or to CHA if DEN has conveyed a first potential 1st round pick to OKC by 2029 0']
# ['2030', '1-5 Own; 6-30 to OKC if DEN has conveyed a first potential 1st round pick to OKC by 2028 1', 'To OKC (via CHA) 0']
# ['2031', 'Own 1', 'To CHA (via PHX) 0']
# ['2032', 'To BRK 0', 'Own 1']
# ----------------------------------------
# Team: Detroit Pistons Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own 1', 'Most favorable of DET, ORL and MIL to BOS; second most favorable to ORL and least favorable to NYK (via MIL to ORL; via DET to LAC to ORL; via ORL to PHX to BRK to NYK) ; CHA 56-60 (via NYK to ATL to SAN to SAC) 1']
# ['2027', 'Own 1', 'Own ; Less favorable of BRK and DAL (via DAL to BRK to DET) ; MIL (via PHL) 3']
# ['2028', 'Own 1', '31-55 Own * ; 56-60 to PHL ; Less favorable of CHA and LAC* (via CHA to DAL) ; MIA* if DAL conveys 1st round pick to CHA in 2027 (via SAN to DAL) ; NYK* *Least favorable of these to UTH 1 + 2']
# ['2029', 'Own 1', 'Two most favorable of DET, MIL and NYK then other to SAC (via MIL to BRK to DET; via NYK to DET) 2']
# ['2030', 'Own 1', 'Own ; MIN 2']
# ['2031', 'Own 1', 'Own ; DAL (via PHL) ; Less favorable of GOS and MIN (via MIN swap for GOS) 3']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Golden State Warriors Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own 1', 'More favorable of GOS and DEN to CHA then other to MIN (via GOS to ATL to OKC to NYK to CHA; via DEN to PHX to CHA; via CHA to PHX to MIN) 0']
# ['2027', 'Own 1', 'More favorable of GOS and PHX to PHL then other to WAS (via WAS) 0']
# ['2028', 'Own 1', 'To PHL (via POR to WAS) 0']
# ['2029', 'Own 1', 'To BRK 0']
# ['2030', '1-20 Own; 21-30 to WAS 1', 'To WAS if GOS does not convey 1st round pick to WAS in 2030 1']
# ['2031', 'Own 1', 'More favorable of GOS and MIN to MIN then other to DET (via MIN swap for GOS) 0']
# ['2032', 'Own 1', '31-50 Own; 51-60 to MEM 1']
# ----------------------------------------
# Team: Houston Rockets Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', '1-4 Own; two most / more favorable of HOU 5-30, LAC and OKC to OKC then other to WAS (via OKC to PHL) 1', 'To OKC if HOU 1-4 in 2026 ; CHI (via WAS) 1 + 1']
# ['2027', 'Own or swap for BRK ; PHX (via BRK) 2', 'Most favorable of HOU, OKC, IND and MIA to OKC; second and third most favorable to NYK; more favorable of (i) SAN and (ii) least favorable of HOU, OKC, IND and MIA to SAN then least favorable of all to MIA (via HOU to DET to OKC to NYK; via MIA to OKC to UTH to SAN to MIA) ; MEM (via LAC) ; Less favorable of POR and NOP if either or both 56-60 (via POR to BOS) 1 + 1']
# ['2028', 'Own 1', 'Own (via ATL) 1']
# ['2029', 'Two most favorable of HOU, DAL and PHX then other to BRK (via DAL and PHX to BRK; via DAL or PHX to HOU; via HOU swap for DAL or PHX) 2', 'To WAS (via OKC) ; SAC (via WAS) 1']
# ['2030', 'Own 1', 'To OKC 0']
# ['2031', 'Own 1', '31-55 Own or ATL (via ATL swap for HOU) ; 56-60 to BOS 1']
# ['2032', 'Own 1', 'More favorable of HOU and PHX to MIN then other to PHX (via PHX) 0']
# ----------------------------------------
# Team: Indiana Pacers Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own (via TOR to NOP) 1', 'More favorable of (i) SAN and (ii) less favorable of IND and MIA to SAN then least favorable of all to MIN; less favorable of (i) BOS and (ii) more favorable of IND and MIA to ATL then most favorable of all to MEM or to BRK [MEM can swap this pick for LAC; LAC then conveyed to HOU which then conveyed to BRK] (via MIA to IND; via SAN swap for IND or MIA; via MIL to MEM; via MEM swap of IND or MIA for BOS; via BOS to ATL) ; TOR 56-60 1']
# ['2027', 'Own 1', 'Most favorable of IND, OKC, HOU and MIA to OKC; second and third most favorable to NYK; more favorable of (i) SAN and (ii) least favorable of IND, OKC, HOU and MIA to SAN then least favorable of all to MIA (via HOU to DET to OKC to NYK; via MIA to OKC to UTH to SAN to MIA) ; UTH (via CLE) 1']
# ['2028', 'Own 1', 'More favorable of IND and PHX then other to NYK (via IND) ; DAL (via SAC) 2']
# ['2029', 'Own 1', 'More favorable of IND and WAS then other to POR (via IND to NYK) 1']
# ['2030', 'Own 1', 'Own 1']
# ['2031', 'Own 1', 'Least favorable of IND, MIA and MEM; more favorable of IND and MIA to WAS; more favorable of (i) MEM and (ii) less favorable of IND and MIA to MEM (via MIA swap for IND; via UTH to WAS; via MEM swap for IND or MIA) 1']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Los Angeles Clippers Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Two most / more favorable of LAC, HOU 5-30 and OKC to OKC then other to WAS (via OKC to PHL) 0', 'Less favorable of (i) LAC and (ii) most favorable of BOS, IND and MIA to BRK then most favorable of all to MEM (via MIA to IND to MIL; via MEM swap of IND or MIA for BOS; via MEM swap of BOS, IND or MIA for LAC; via LAC to HOU to BRK) ; MEM 31-42 (via UTH to ATL) 1']
# ['2027', 'Least / less favorable of LAC, DEN 6-30 and OKC (via OKC swap of OKC or DEN for LAC) 1', 'To UTH (via ATL to LAC) 0']
# ['2028', 'To PHL 0', 'More favorable of LAC and CHA to CHA then other to DET [DET may convey to UTH] (via CHA to DAL) 0']
# ['2029', '1-3 Own; 4-30 Own or PHL (via PHL swap for LAC) 1', 'To SAN (via PHL) 0']
# ['2030', 'Own 1', 'More favorable of LAC and UTH to CHA then other to LAC (via LAC to UTH) 0']
# ['2031', 'Own 1', 'Own 1']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Los Angeles Lakers Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own 1', 'To TOR (via CLE to MIA) 0']
# ['2027', '1-4 Own; 5-30 to UTH 1', 'To BRK if LAL conveys 1st round pick to UTH in 2027 or to UTH if LAL does not convey 1st round pick to UTH in 2027 0']
# ['2028', 'Own 1', 'More favorable of LAL and WAS to ORL then other to WAS (via WAS to LAL to ORL; via LAL to WAS) 0']
# ['2029', 'To DAL 0', 'To WAS 0']
# ['2030', 'Own 1', 'To BRK 0']
# ['2031', 'Own 1', 'To BRK 0']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Memphis Grizzlies Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Two most favorable of (i) MEM, (ii) less favorable of PHX and WAS 1-8 [or (ii) PHX if WAS not conveyable] and (iii) ORL then least favorable of (i), (ii) and (iii) to CHA (via WAS swap for PHX; via MEM swap of ORL for PHX or WAS; via MEM swap for PHX, WAS or ORL; via PHX to CHA) 2', '31-42 to LAC (via UTH to ATL) ; 43-60 to POR (via UTH to GOS) ; Most favorable LAC, BOS, IND and MIA (via MIA to IND; via MIL to MEM; via MEM swap of IND or MIA for BOS; via MEM swap of BOS, IND or MIA for LAC) 1']
# ['2027', 'Own 1', 'To HOU (via LAC) 0']
# ['2028', 'Own 1', 'To BRK (via PHX) 0']
# ['2029', 'Own or swap for ORL 3-30 1', 'To BRK (via PHX) ; ORL if ORL 1-2 in 2029 ; POR (via PHL to IND) 1 + 1']
# ['2030', 'More favorable of (i) MEM and (ii) less favorable of PHX and WAS then least favorable of all to PHX (via WAS swap for PHX; via MEM swap for PHX or WAS) ; ORL 2', '31-50 Own; 51-60 to MIN 1']
# ['2031', 'Own 1', 'More favorable of (i) MEM and (ii) less favorable of IND and MIA then least favorable of all to IND (via MIA swap for IND; via MEM swap for IND or MIA) 1']
# ['2032', 'Own 1', 'Own ; GOS 51-60 1 + 1']
# ----------------------------------------
# Team: Miami Heat Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own 1', 'More favorable of (i) SAN and (ii) less favorable of MIA and IND to SAN then least favorable of all to MIN; less favorable of (i) BOS and (ii) more favorable of MIA and IND to ATL then most favorable of all to MEM or to BRK [MEM can swap this pick for LAC; LAC then conveyed to HOU which then conveyed to BRK] (via MIA to IND; via SAN swap for IND or MIA; via MIL to MEM; via MEM swap of IND or MIA for BOS; via BOS to ATL) 0']
# ['2027', '1-14 Own; 15-30 to CHA 1', 'Least favorable of MIA, OKC, HOU, IND and SAN; most favorable of MIA, OKC, HOU and IND to OKC; second and third most favorable to NYK; more favorable of (i) SAN and (ii) least favorable of MIA, OKC, HOU and IND to SAN (via MIA to OKC to UTH to SAN to MIA; via HOU to DET to OKC to NYK) 1']
# ['2028', 'To CHA if not already settled 1', 'To DET if DAL conveys 1st round pick to CHA in 2027 or to CHA if DAL does not convey 1st round pick to CHA in 2027 [DET may convey to UTH] (via SAN to DAL) 0']
# ['2029', 'Own 1', 'To OKC 0']
# ['2030', 'Own 1', 'To OKC 0']
# ['2031', 'Own 1', 'More favorable of MIA and IND to WAS; more favorable of (i) MEM and (ii) less favorable of MIA and IND to MEM then least favorable of all to IND (via MIA swap for IND; via UTH to WAS; via MEM swap for IND or MIA) 0']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Milwaukee Bucks Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Less favorable of MIL and NOP then other to ATL (via NOP swap for MIL) 1', 'Most favorable of MIL, ORL and DET to BOS; second most favorable to ORL and least favorable to NYK (via MIL to ORL; via DET to LAC to ORL; via ORL to PHX to BRK to NYK) ; UTH 56-60 (via MIN to SAN) 1']
# ['2027', 'More favorable of MIL and NOP to NOP then other to ATL if 5-30 or MIL and NOP to NOP if both 1-4 (via NOP) 0', 'To DET (via PHL) 0']
# ['2028', 'Less favorable of (i) less favorable of MIL and POR 1-14 if POR has not conveyed 1st round pick to CHI by 2027 [or (i) MIL if POR not conveyable], and (ii) more favorable of (a) WAS and (b) least / less favorable of BRK, PHL 9-30 if PHL conveys 1st round pick to OKC in 2026, and PHX then more favorable of (i) and (ii) to WAS; or Less favorable of (i) less favorable of MIL and POR if POR has conveyed 1st round pick to CHI by 2027, and (ii) more favorable of (a) WAS and (b) least / less favorable of BRK, PHL 9-30 if PHL conveys 1st round pick to OKC in 2026, and PHX then more favorable of (i) and (ii) to WAS (via POR swap for MIL; via BRK swap of BRK or PHL for PHX; via WAS swap for PHX, BRK or PHL; via WAS swap of WAS, BRK, PHL or PHX for MIL or POR) 1', 'To OKC (via BRK to HOU) 0']
# ['2029', 'Most and least favorable of MIL, BOS and POR to POR; second most favorable to WAS (via BOS to POR; via MIL to POR; via POR to WAS) 0', 'Two most favorable of MIL, DET and NYK to DET then other to SAC (via MIL to BRK to DET; via NYK to DET) 0']
# ['2030', 'Own or POR (via POR swap for MIL) 1', 'To ORL 0']
# ['2031', 'Own 1', 'To CHA 0']
# ['2032', 'Own 1', 'To CHA 0']
# ----------------------------------------
# Team: Minnesota Timberwolves Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Less favorable of MIN and UTH 1-8 [or MIN if UTH not conveyable] ; less favorable of (i) CLE and (ii) more favorable of MIN and UTH 1-8 [or CLE if UTH not conveyable] to CLE then most / more favorable of all to UTH [CLE may convey to ATL] (via UTH swap for MIN; via UTH swap of UTH or MIN for CLE) 1', 'Less favorable of MIN and NYK to NYK; most favorable of MIN, NYK, NOP and POR to BOS; less favorable of (i) more favorable of MIN and NYK and (ii) more favorable of NOP and POR to WAS (via MIN to NYK; via NOP to POR to NOP; via POR to DET to BOS; via DET to WAS) ; Less favorable of DEN and GOS (via DEN to PHX to CHA; via GOS to ATL to OKC to NYK to CHA; via CHA to PHX to MIN) ; Least favorable of IND, MIA and SAN (via MIA to IND; via SAN swap for IND or MIA) 2']
# ['2027', 'Two most favorable of MIN, CLE and UTH to UTH then other to PHX (via CLE and MIN to UTH) 0', 'To POR (via HOU to OKC to NYK) ; CLE (via ATL) 1']
# ['2028', 'Own 1', 'To SAN 0']
# ['2029', '1-5 Own; most / two most favorable of MIN 6-30, CLE and UTH to UTH then other to CHA (via CLE and MIN to UTH to PHX) 1', 'To UTH if MIN does not convey 1st round pick to UTH in 2029 1']
# ['2030', '1 Own; less favorable of (i) MIN 2-30 and (ii) more favorable of SAN and DAL then most / more favorable of all to SAN (via SAN swap for DAL; via SAN swap of SAN or DAL for MIN) 1', 'To DET ; MEM 51-60 1']
# ['2031', 'To SAC (via SAN) 0', 'More favorable of MIN and GOS then other to DET (via MIN swap for GOS) 1']
# ['2032', 'Frozen (through 2027-28) 1', 'Own ; More favorable of PHX and HOU (via PHX) 2']
# ----------------------------------------
# Team: New Orleans Pelicans Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'More favorable of NOP and MIL to ATL then other to MIL (via NOP swap for MIL) 0', 'Most favorable of NOP, POR, MIN and NYK to BOS; less favorable of NOP and POR to SAN; less favorable of (i) more favorable of NOP and POR and (ii) more favorable of MIN and NYK to WAS (via NOP to POR to NOP; via POR to DET; via MIN to NYK; via NOP to SAN; via DET to BOS; via DET to WAS) 0']
# ['2027', 'More favorable of NOP and MIL then other to ATL if 5-30 or NOP and MIL if both 1-4 (via NOP) 1 + 1', 'More favorable of NOP and POR to CHA then other to POR [POR may convey to HOU] (via NOP) 0']
# ['2028', 'Own 1', 'To SAN 0']
# ['2029', 'Own 1', 'To SAN 0']
# ['2030', 'Own 1', 'Own or ORL (via ORL swap for NOP) 1']
# ['2031', 'Own 1', 'More favorable of NOP and ORL to ORL then other to OKC (via ORL swap for NOP) ; TOR 1']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: New York Knicks Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own ; WAS 9-30 (via HOU to OKC) 1 + 1', 'Less favorable of NYK and MIN; most favorable of NYK, MIN, NOP and POR to BOS; less favorable of (i) more favorable of NYK and MIN and (ii) more favorable of NOP and POR to WAS (via MIN to NYK; via NOP to POR to NOP; via POR to DET to BOS; via DET to WAS) ; Least favorable of DET, MIL and ORL (via DET to LAC to ORL; via ORL to PHX to BRK to NYK) ; WAS if WAS does not convey 1st round pick to NYK in 2026 (via HOU to OKC) 2 + 1']
# ['2027', 'To BRK 0', 'Own ; WAS if WAS does not convey 1st round pick to NYK in 2026 (via HOU to OKC) ; Second and third most favorable of OKC, HOU, IND and MIA (via HOU to DET to OKC to NYK) 3 + 1']
# ['2028', 'Least favorable of NYK, BRK and PHX if NYK and / or if PHL 9-30 , if PHL conveys 1st round pick to OKC in 2026, is less favorable than BRK and PHX; or second most favorable of NYK, BRK and PHX in all other scenarios ; if (i) PHL 9-30 , if conveyable, is third most favorable and (ii) NYK is most or second most favorable of NYK, BRK, PHL 9-30 if conveyable, and PHX, then most and third most favorable to BRK; or most / two most favorable to BRK in all other scenarios (via BRK swap of BRK or PHL for PHX; via BRK swap of BRK or PHX for NYK; via WAS swap for PHX, BRK or PHL) 1', 'To DET [DET may convey to UTH] ; BOS 46-60 (via ORL to PHX) ; Less favorable of IND and PHX (via IND) 1 + 1']
# ['2029', 'To BRK 0', 'Two most favorable of NYK, DET and MIL to DET then other to SAC (via NYK to DET; via MIL to BRK to DET) 0']
# ['2030', 'Own 1', 'To POR 0']
# ['2031', 'To BRK 0', 'To CHA 0']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Oklahoma City Thunder Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Two most / more favorable of OKC, HOU 5-30 and LAC then other to WAS (via OKC to PHL) ; PHL 5-30; UTH 9-30 1 + 3', 'Most favorable of OKC, DAL and PHL; second most favorable to PHX and least favorable to WAS (via OKC to HOU to PHX; via OKC to MIA to SAN to WAS) ; HOU if HOU 1-4 in 2026 1 + 1']
# ['2027', 'Two most / more favorable of OKC, DEN 6-30 and LAC (via OKC swap of OKC or DEN for LAC) ; PHL 5-30 if not already settled ; SAN 17-30 (via SAC) 1 + 3', 'Most favorable of OKC, HOU, IND and MIA; second and third most favorable to NYK; more favorable of (i) SAN and (ii) least favorable of OKC, HOU, IND and MIA to SAN then least favorable of all to MIA (via HOU to DET to OKC to NYK; via MIA to OKC to UTH to SAN to MIA) ; CHA if SAN 1-16 in 2027 (via SAC) ; SAC if SAN 1-16 in 2027; PHL if PHL has not conveyed 1st round pick to OKC by 2027 1 + 3']
# ['2028', 'Own or swap for DAL ; DEN 6-30 if not already settled 1 + 1', 'Own ; MIL (via BRK to HOU) ; UTH 3']
# ['2029', 'Own ; DEN 6-30 if not already settled ; or DEN 6-30 if DEN has conveyed a first potential 1st round pick to OKC by 2027 1 + 1', 'Own ; ATL; BOS; DEN if DEN has not conveyed a first potential 1st round pick to OKC by 2029 ; MIA 4 + 1']
# ['2030', 'Own ; DEN 6-30 if not already settled and if DEN has conveyed a first potential 1st round pick to OKC by 2028 1 + 1', 'Own ; DEN (via CHA) ; HOU; MIA 4']
# ['2031', 'Own 1', 'Own ; Less favorable of NOP and ORL (via ORL swap for NOP) 2']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Orlando Magic Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Two most favorable of (i) ORL, (ii) less favorable of PHX and WAS 1-8 [or (ii) PHX if WAS not conveyable] and (iii) MEM to MEM then least favorable of all to CHA (via WAS swap for PHX; via MEM swap of ORL for PHX or WAS; via MEM swap for PHX, WAS or ORL; via PHX to CHA) 0', 'Second most favorable of ORL, DET and MIL; most favorable to BOS and least favorable to NYK (via MIL to ORL; via DET to LAC to ORL; via ORL to PHX to BRK to NYK) 1']
# ['2027', 'Own 1', 'Less favorable of ORL and BOS then other to BOS (via ORL) 1']
# ['2028', 'To POR (via MEM) 0', 'Own ; More favorable of LAL and WAS (via LAL) 2']
# ['2029', '1-2 Own; 3-30 Own or MEM (via MEM swap for ORL) 1', 'To MEM if ORL 1-2 in 2029 1']
# ['2030', 'To MEM 0', 'Own or swap for NOP ; MIL 2']
# ['2031', 'Own 1', 'More favorable of ORL and NOP then other to OKC (via ORL swap for NOP) 1']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Philadelphia Sixers Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', '1-4 Own; 5-30 to OKC 1', 'Most favorable of PHL, OKC and DAL to OKC; second most favorable to PHX and least favorable to WAS (via OKC to HOU to PHX; via OKC to MIA to SAN to WAS) 0']
# ['2027', '1-4 Own; 5-30 to OKC if not already settled 1', 'To OKC if PHL has not conveyed 1st round pick to OKC by 2027 ; More favorable of GOS and PHX (via WAS) 1 + 1']
# ['2028', '1-8 Own; if (i) PHL 9-30 , if PHL conveys 1st round pick to OKC in 2026, is third most favorable and (ii) NYK is most or second most favorable of PHL 9-30 if conveyable , PHX, BRK and NYK, then most and third most favorable to BRK; or most / two most favorable to BRK in all other scenarios ; least favorable of PHX, BRK and NYK to NYK if NYK and / or if PHL 9-30 , if conveyable, is less favorable than PHX and BRK; or second most favorable of PHX, BRK and NYK to NYK in all other scenarios ; more favorable of (i) WAS and (ii) least / less favorable of PHL 9-30 if conveyable , PHX and BRK to WAS then least favorable of all to PHX [WAS can then swap with MIL] (via BRK swap of BRK or PHL for PHX; via BRK swap of BRK or PHX for NYK; via WAS swap for PHX, BRK or PHL) ; LAC 1 + 1', 'To BRK if PHL does not convey 1st round pick to BRK in 2028 ; DET 56-60; GOS (via POR to WAS) 1 + 2']
# ['2029', 'Own or swap for LAC 4-30 1', 'Own 1']
# ['2030', 'Own 1', 'To DAL ; More favorable of PHX and POR (via WAS) ; WAS 2']
# ['2031', 'Own 1', 'Own 1']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Phoenix Suns Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'More favorable of PHX and WAS 1-8 to WAS [or neither to WAS if WAS not conveyable] ; two most favorable of (i) less favorable of PHX and WAS 1-8 [or (ii) PHX if WAS not conveyable] , (ii) MEM and (iii) ORL to MEM then least favorable of all to CHA (via WAS swap for PHX; via MEM swap of ORL for PHX or WAS; via MEM swap for PHX, WAS or ORL; via PHX to CHA) 0', 'To WAS ; Second most favorable of OKC, DAL and PHL (via OKC to HOU) 1']
# ['2027', 'To HOU (via BRK) ; Least favorable of UTH, CLE and MIN (via CLE and MIN to UTH) 1', 'More favorable of PHX and GOS to PHL then other to WAS (via WAS) 0']
# ['2028', 'Least favorable of PHX, PHL 9-30 if PHL conveys 1st round pick to OKC in 2026, WAS and BRK; more favorable of (i) WAS and (ii) least / less favorable of PHX, PHL 9-30 if conveyable, and BRK to WAS; if (i) PHL 9-30 , if conveyable, is third most favorable and (ii) NYK is most or second most favorable of PHX, BRK and PHL 9-30 if conveyable, and NYK, then most and third most favorable to BRK; or most / two most favorable to BRK in all other scenarios ; least favorable of PHX, BRK and NYK to NYK if NYK and / or if PHL 9-30 , if conveyable, is less favorable than PHX and BRK; or second most favorable of PHX, BRK and NYK to NYK in all other scenarios [WAS can then swap with MIL] (via BRK swap of BRK or PHL for PHX; via BRK swap of BRK or PHX for NYK; via WAS swap for PHX, BRK or PHL) 1', 'More favorable of PHX and IND to IND then other to NYK (via IND) 0']
# ['2029', 'Two most favorable of PHX, DAL and HOU to HOU then other to BRK (via DAL and PHX to BRK; via DAL or PHX to HOU; via HOU swap for DAL or PHX) 0', 'Own (via OKC to CHA) 1']
# ['2030', 'Least favorable of PHX, WAS and MEM; more favorable of PHX and WAS to WAS; more favorable of (i) MEM and (ii) less favorable of PHX and WAS to MEM (via WAS swap for PHX; via MEM swap for PHX or WAS) 1', 'More favorable of PHX and POR to PHL then other to WAS (via WAS) 0']
# ['2031', 'To UTH 0', 'To CHA 0']
# ['2032', 'Frozen (through 2027-28) 1', 'Less favorable of PHX and HOU then other to MIN (via PHX) 1']
# ----------------------------------------
# Team: Portland Trail Blazers Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', '1-14 Own; 15-30 to CHI 1', 'Most favorable of POR, NOP, MIN and NYK to BOS; less favorable of POR and NOP to SAN; less favorable of (i) more favorable of POR and NOP and (ii) more favorable of MIN and NYK to WAS (via NOP to POR to NOP; via POR to DET; via MIN to NYK; via NOP to SAN; via DET to BOS; via DET to WAS) ; MEM 43-60 (via UTH to GOS) 1']
# ['2027', '1-14 Own; 15-30 to CHI if not already settled 1', 'Less favorable of POR and NOP then other to CHA [POR may convey to HOU; see following] ; then less favorable of POR and NOP to HOU if either or both 56-60 (via POR to NOP to CHA; via POR to BOS to HOU) ; ATL (via BOS to MEM) ; MIN (via HOU to OKC to NYK) 2 + 1']
# ['2028', '1-14 Own or swap for MIL; 15-30 to CHI if not already settled ; or Own or swap for MIL if POR has conveyed 1st round pick to CHI by 2027 [WAS can then swap with MIL] ; ORL (via MEM) 1 + 1', 'To CHI if POR has not conveyed 1st round pick to CHI by 2028 ; SAC (via CHI to SAC to MEM) 1 + 1']
# ['2029', 'Most and least favorable of POR, BOS and MIL; second most favorable to WAS (via BOS to POR; via MIL to POR; via POR to WAS) 2', 'To MEM (via PHL to IND) ; Less favorable of IND and WAS (via IND to NYK) 1']
# ['2030', 'Own or swap for MIL 1', 'More favorable of POR and PHX to PHL then other to WAS (via WAS) ; NYK 1']
# ['2031', 'Own 1', 'Own 1']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Sacramento Kings Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own 1', 'Own ; CHA 31-55 (via NYK to ATL to SAN) 1 + 1']
# ['2027', 'Own ; SAN 1-16 1 + 1', 'To OKC if SAN 1-16 in 2027 ; CHA if SAN 17-30 in 2027 (via NYK to ATL to SAN) 2']
# ['2028', 'Own 1', 'To POR (via CHI to SAC to MEM) 0']
# ['2029', 'Own 1', 'To HOU (via WAS) ; Least favorable of DET, MIL and NYK (via MIL to BRK to DET; via NYK to DET) 1']
# ['2030', 'Own 1', 'To SAN (via IND) 0']
# ['2031', 'Own or SAN (via SAN swap for SAC) ; MIN (via SAN) 2', 'To SAN 0']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: San Antonio Spurs Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own or swap for ATL [ATL may convey to CLE] 1', 'More favorable of (i) SAN and (ii) less favorable of IND and MIA then least favorable of all to MIN (via MIA to IND; via SAN swap for IND or MIA) ; Less favorable of NOP and POR (via NOP to POR to NOP to SAN) ; UTH 31-55 (via MIN) 2 + 1']
# ['2027', '1-16 to SAC; 17-30 to OKC (via SAC) ; ATL 1', 'More favorable of (i) SAN and (ii) least favorable of OKC, HOU, IND and MIA then least favorable of all to MIA (via HOU to DET to OKC; via MIA to OKC to UTH to SAN to MIA) 1']
# ['2028', 'Own or swap for BOS 2-30 1', 'Own ; BOS 31-45 if BOS 1 in 2028 ; MIN; NOP 3 + 1']
# ['2029', 'Own 1', 'Own ; LAC (via PHL) ; NOP 3']
# ['2030', 'Most / more favorable of SAN, DAL and MIN 2-30; less favorable of SAN and DAL to DAL; less favorable of (i) MIN 2-30 and (ii) more favorable of SAN and DAL [or MIN if MIN not conveyable] to MIN (via SAN swap for DAL; via SAN swap of SAN or DAL for MIN) 1', 'Own ; CLE; SAC (via IND) 3']
# ['2031', 'Own or swap for SAC 1', 'Own ; SAC 2']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Toronto Raptors Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Own 1', '31-55 Own; 56-60 to IND ; LAL (via CLE to MIA) 1 + 1']
# ['2027', 'Own 1', 'Own 1']
# ['2028', 'Own 1', 'Own 1']
# ['2029', 'Own 1', 'Own 1']
# ['2030', 'Own 1', 'Own 1']
# ['2031', 'Own 1', 'To NOP 0']
# ['2032', 'Own 1', 'Own 1']
# ----------------------------------------
# Team: Utah Jazz Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', 'Most / more favorable of UTH 1-8, MIN and CLE; less favorable of UTH 1-8 and MIN [or MIN if UTH not conveyable] to MIN; less favorable of (i) CLE and (ii) more favorable of UTH 1-8 and MIN [or CLE if UTH not conveyable] to CLE [CLE may convey to ATL] ; UTH 9-30 to OKC (via UTH swap for MIN; via UTH swap of UTH or MIN for CLE) 1', '31-55 to SAN; 56-60 to MIL (via MIN to SAN) 0']
# ['2027', 'Two most favorable of UTH, CLE and MIN then other to PHX (via CLE and MIN to UTH) ; LAL 5-30 2 + 1', 'To IND (via CLE) ; LAC (via ATL to LAC) ; LAL if LAL does not convey 1st round pick to UTH in 2027 1 + 1']
# ['2028', 'Own or swap for CLE [CLE may convey UTH to ATL] 1', 'To OKC ; Least favorable of (i) DET 31-55, (ii) less favorable of CHA and LAC (via CHA to DAL to DET) , (iii) MIA if DAL conveys 1st round pick to CHA in 2027 (via SAN to DAL to DET) and (iv) NYK (via DET) 1']
# ['2029', 'Most / two most favorable of UTH, CLE and MIN 6-30 then other to CHA (via CLE and MIN to UTH to PHX) 1 + 1', 'Own ; MIN if MIN does not convey 1st round pick to UTH in 2029 1 + 1']
# ['2030', 'Own 1', 'Less favorable of UTH and LAC then other to CHA (via LAC to UTH) 1']
# ['2031', 'Own ; PHX 2', 'Own 1']
# ['2032', 'Own 1', 'To WAS 0']
# ----------------------------------------
# Team: Washington Wizards Future NBA Draft Picks
# Headers: ['Year', 'First Round', 'Second Round']
# ['2026', '1-8 Own or swap for PHX; two most favorable of (i) less favorable of WAS 1-8 and PHX [or (ii) PHX if WAS not conveyable] , (ii) MEM and (iii) ORL to MEM then least favorable of all to CHA (via WAS swap for PHX; via MEM swap of ORL for PHX or WAS; via MEM swap for PHX, WAS or ORL; via PHX to CHA) ; WAS 9-30 to NYK (via HOU to OKC) ; Least / less favorable of OKC, HOU 5-30 and LAC (via OKC to PHL) 1 + 1', 'To NYK if WAS does not convey 1st round pick to NYK in 2026 (via HOU to OKC) ; Less favorable of (i) more favorable of MIN and NYK and (ii) more favorable of NOP and POR (via MIN to NYK; via NOP to POR to NOP; via POR to DET to WAS) ; Least favorable of OKC, DAL and PHL (via OKC to MIA to SAN) ; PHX 3 + 1']
# ['2027', 'Own 1', 'To NYK if WAS does not convey 1st round pick to NYK in 2026 (via HOU to OKC) ; More favorable of BRK and DAL (via DAL to BRK to DET; via DET to WAS) ; CHI (in separate, protected conveyances; via WAS to NOP) ; Less favorable of GOS and PHX 3 + 1']
# ['2028', 'More favorable of (i) more favorable of (a) WAS and (b) least / less favorable of BRK, PHL 9-30 if PHL conveys 1st round pick to OKC in 2026, and PHX and (ii) less favorable of MIL and POR 1-14 if POR has not conveyed 1st round pick to CHI by 2027 [or (ii) MIL if POR not conveyable] then less favorable of (i) and (ii) to MIL; or More favorable of (i) more favorable of (a) WAS and (b) least / less favorable of BRK, PHL 9-30 if PHL conveys 1st round pick to OKC in 2026, and PHX and (ii) less favorable of MIL and POR if POR has conveyed 1st round pick to CHI by 2027, then less favorable of (i) and (ii) to MIL; least favorable of WAS, PHL 9-30 if PHL does not convey 1st round pick to BRK in 2027 and if PHL has conveyed 1st round pick to OKC by 2026 , BRK and PHX to PHX (via POR swap for MIL; via BRK swap of BRK or PHL for PHX; via WAS swap for PHX, BRK or PHL; via WAS swap of WAS, BRK, PHL or PHX for MIL or POR) 1', 'Less favorable of WAS and LAL then other to ORL (via WAS to LAL to ORL; via LAL to WAS) ; DEN 34-60 (via SAN to SAC) 1 + 1']
# ['2029', 'Own ; Second most favorable of POR, BOS and MIL (via BOS to POR; via MIL to POR; via POR to WAS) 2', 'More favorable of WAS and IND to IND then other to POR (via IND to NYK) ; HOU (via OKC) ; LAL 2']
# ['2030', 'More favorable of WAS and PHX; more favorable of (i) MEM and (ii) less favorable of WAS and PHX to MEM then least favorable of all to PHX (via WAS swap for PHX; via MEM swap for WAS or PHX) ; GOS 21-30 1 + 1', 'To PHL ; GOS if GOS does not convey 1st round pick to WAS in 2030 ; Less favorable of PHX and POR 1 + 1']
# ['2031', 'Own 1', 'Own ; More favorable of MIA and IND (via MIA swap for IND; via UTH) 2']
# ['2032', 'Own 1', 'Own ; UTH 2']
# ----------------------------------------

# %%
import json
import pandas as pd

# Prepare documents for RAG/FAISS: one document per team-year-round
rag_docs = []
for team_info in team_tables:
    team = team_info['team']
    headers = team_info['headers']
    for row in team_info['rows']:
        if len(row) != len(headers):
            continue
        year = row[0]
        first_round = row[1] if len(row) > 1 else ""
        second_round = row[2] if len(row) > 2 else ""
        # Add first round as a doc
        rag_docs.append({
            'team': team,
            'year': year,
            'round': 'First',
            'details': first_round.strip()
        })
        # Add second round as a doc
        rag_docs.append({
            'team': team,
            'year': year,
            'round': 'Second',
            'details': second_round.strip()
        })

# Save as CSV for tabular use
pd.DataFrame(rag_docs).to_csv('nba_draft_picks_rag.csv', index=False)

# Save as JSONL for vector DB (FAISS) ingestion
with open('nba_draft_picks_rag.jsonl', 'w') as f:
    for doc in rag_docs:
        f.write(json.dumps(doc) + '\n')

print('Saved nba_draft_picks_rag.csv and nba_draft_picks_rag.jsonl')
# Out:
# Saved nba_draft_picks_rag.csv and nba_draft_picks_rag.jsonl

# %%
import pandas as pd

# Prepare a dictionary to collect picks: {team: {year: "1st" or ""}}
picks = {}

for table in tables:
    team_name = table.find_previous("h2").text.strip()
    if team_name not in picks:
        picks[team_name] = {}
    for row in table.select("tr")[1:]:
        cols = [td.text.strip() for td in row.find_all("td")]
        if not cols or len(cols) < 3:
            continue
        year = cols[0]
        round_info = cols[1]
        if "1st" in round_info:
            picks[team_name][year] = "1st"

# Get all unique years
all_years = sorted({year for team in picks for year in picks[team]})

# Build DataFrame
df = pd.DataFrame(index=picks.keys(), columns=all_years)
for team in picks:
    for year in all_years:
        df.loc[team, year] = picks[team].get(year, "")

# Save to CSV
df.to_csv("nba_first_round_picks.csv")
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#### Retrieving payroll notes

# %%
import requests
from bs4 import BeautifulSoup

# URL for Atlanta Hawks contracts page
url = 'https://www.basketball-reference.com/contracts/ATL.html'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find the Payroll Notes section (usually in a div with id='all_payroll' or similar)
payroll_notes = []
for comment in soup.find_all(string=lambda text: isinstance(text, (str)) and 'Payroll Notes' in text):
    # Find the parent div or section containing the notes
    parent = comment.find_parent(['div', 'section'])
    if parent:
        # Extract all text after 'Payroll Notes' header
        notes = parent.get_text(separator='\n', strip=True)
        payroll_notes.append(notes)

# Fallback: look for any <ul> or <li> under a Payroll Notes header
if not payroll_notes:
    for h2 in soup.find_all(['h2', 'h3']):
        if 'Payroll Notes' in h2.text:
            ul = h2.find_next('ul')
            if ul:
                notes = [li.get_text(strip=True) for li in ul.find_all('li')]
                payroll_notes.extend(notes)

print('Payroll Notes:')
for note in payroll_notes:
    print(note)
# Out:
# Payroll Notes:

# %%
response
# Out:
# <Response [403]>
